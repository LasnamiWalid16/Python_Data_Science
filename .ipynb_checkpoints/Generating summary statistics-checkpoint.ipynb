# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import seaborn as sb
import scipy
from scipy import stats

# %%
# Chapter 5 - Basic Math and Statistics
## Segment 3 - Generating summary statistics using pandas and scipy

# %%
cars=pd.read_csv('mtcars.csv')
cars.head()
# Out:
#           Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
cars.columns=['car_names','mpg','cyl','disp','hp','drat','wt','qsec','vs','am','gear','carb']

# %%
cars.head()
# Out:
#            car_names   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
cars.index=cars.car_names

# %%
cars.head()
# Out:
#                            car_names   mpg  cyl   disp   hp  drat     wt  \
# car_names
# Mazda RX4                  Mazda RX4  21.0    6  160.0  110  3.90  2.620
# Mazda RX4 Wag          Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875
# Datsun 710                Datsun 710  22.8    4  108.0   93  3.85  2.320
# Hornet 4 Drive        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215
# Hornet Sportabout  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440
#
#                     qsec  vs  am  gear  carb
# car_names
# Mazda RX4          16.46   0   1     4     4
# Mazda RX4 Wag      17.02   0   1     4     4
# Datsun 710         18.61   1   1     4     1
# Hornet 4 Drive     19.44   1   0     3     1
# Hornet Sportabout  17.02   0   0     3     2

# %% [markdown]
# <h4>Using Count values to count the number of cars for each carb type</h4>

# %%
cars.carb.value_counts()
# Out:
# 2    10
# 4    10
# 1     7
# 3     3
# 6     1
# 8     1
# Name: carb, dtype: int64

# %% [markdown]
# <h4>Pearson Correlation</h4>

# %%
corr= cars.corr()
corr
# Out:
#            mpg       cyl      disp        hp      drat        wt      qsec  \
# mpg   1.000000 -0.852162 -0.847551 -0.776168  0.681172 -0.867659  0.418684
# cyl  -0.852162  1.000000  0.902033  0.832447 -0.699938  0.782496 -0.591242
# disp -0.847551  0.902033  1.000000  0.790949 -0.710214  0.887980 -0.433698
# hp   -0.776168  0.832447  0.790949  1.000000 -0.448759  0.658748 -0.708223
# drat  0.681172 -0.699938 -0.710214 -0.448759  1.000000 -0.712441  0.091205
# wt   -0.867659  0.782496  0.887980  0.658748 -0.712441  1.000000 -0.174716
# qsec  0.418684 -0.591242 -0.433698 -0.708223  0.091205 -0.174716  1.000000
# vs    0.664039 -0.810812 -0.710416 -0.723097  0.440278 -0.554916  0.744535
# am    0.599832 -0.522607 -0.591227 -0.243204  0.712711 -0.692495 -0.229861
# gear  0.480285 -0.492687 -0.555569 -0.125704  0.699610 -0.583287 -0.212682
# carb -0.550925  0.526988  0.394977  0.749812 -0.090790  0.427606 -0.656249
#
#             vs        am      gear      carb
# ...

# %%
corr >0.7
# Out:
#         mpg    cyl   disp     hp   drat     wt   qsec     vs     am   gear  \
# mpg    True  False  False  False  False  False  False  False  False  False
# cyl   False   True   True   True  False   True  False  False  False  False
# disp  False   True   True   True  False   True  False  False  False  False
# hp    False   True   True   True  False  False  False  False  False  False
# drat  False  False  False  False   True  False  False  False   True  False
# wt    False   True   True  False  False   True  False  False  False  False
# qsec  False  False  False  False  False  False   True   True  False  False
# vs    False  False  False  False  False  False   True   True  False  False
# am    False  False  False  False   True  False  False  False   True   True
# gear  False  False  False  False  False  False  False  False   True   True
# carb  False  False  False   True  False  False  False  False  False  False
#
#        carb
# mpg   False
# cyl   False
# disp  False
# hp     True
# ...

# %%
sb.heatmap(corr, xticklabels=corr.columns.values,yticklabels=corr.columns.values)
# Out:
# <AxesSubplot:>

# %%
cars.head()
# Out:
#                            car_names   mpg  cyl   disp   hp  drat     wt  \
# car_names
# Mazda RX4                  Mazda RX4  21.0    6  160.0  110  3.90  2.620
# Mazda RX4 Wag          Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875
# Datsun 710                Datsun 710  22.8    4  108.0   93  3.85  2.320
# Hornet 4 Drive        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215
# Hornet Sportabout  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440
#
#                     qsec  vs  am  gear  carb
# car_names
# Mazda RX4          16.46   0   1     4     4
# Mazda RX4 Wag      17.02   0   1     4     4
# Datsun 710         18.61   1   1     4     1
# Hornet 4 Drive     19.44   1   0     3     1
# Hornet Sportabout  17.02   0   0     3     2

# %%
test=cars[['cyl','vs']]
vsgroup=test.groupby('vs')
vsgroup.describe()
# Out:
#      cyl
#    count      mean       std  min  25%  50%  75%  max
# vs
# 0   18.0  7.444444  1.149026  4.0  8.0  8.0  8.0  8.0
# 1   14.0  4.571429  0.937614  4.0  4.0  4.0  5.5  6.0

# %%
pd.crosstab(cars['vs'],cars['cyl'])
